# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
t = np.arange(0, 20, 1)
r = 2
분자 = np.array([r**x for x in t])
분모 = np.array([r**(x+2) for x in t])
plt.xlabel('n')
plt.plot(분자, 'r-', 분모, 'g-')
plt.show()

# %%
분자_나누기_분모 = 분자/분모
plt.plot(분자_나누기_분모, 'b-')
plt.ylim([0,1])
plt.show()

# %%
아보가드로수 = 6.02*10^23
탄소원자량 = 12
수소원자량 = 1
CH4분자량 = 탄소원자량 + 4*수소원자량

실제_내책상_위에_갖다놓은_CH4_질량 = 36

우리가_모르는_분자의_실제_개수
